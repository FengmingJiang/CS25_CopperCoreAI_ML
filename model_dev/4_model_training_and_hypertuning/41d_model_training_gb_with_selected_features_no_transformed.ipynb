# %% [markdown]
# # Gradient Boosting - Hyperparameter Tuning & Training (Selected Features)

# %%
# Core Libraries
import pandas as pd
import numpy as np
import joblib
import matplotlib.pyplot as plt
from scipy.stats import randint, uniform

# Models and Calibration
from sklearn.ensemble import GradientBoostingClassifier # Or import XGBClassifier, LGBMClassifier
from sklearn.calibration import CalibratedClassifierCV, calibration_curve

# Model Selection
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV, StratifiedKFold

# Scoring and Evaluation
from sklearn.metrics import (
    classification_report,
    confusion_matrix,
    ConfusionMatrixDisplay,
    precision_recall_curve,
    average_precision_score,
    roc_curve,
    RocCurveDisplay,
    auc,
    brier_score_loss,
    make_scorer,
    PrecisionRecallDisplay,
    roc_auc_score
)

# %% [markdown]
# ## 1. Load Data

# %%
try:
    X_train = pd.read_csv('../../data/processed/no_transformed/X_train_no_transform_selected.csv') # Contains selected features
    y_train = pd.read_csv('../../data/processed/no_transformed/y_train_no_transform_scaled_resampled.csv').values.ravel() # Flatten the array to 1D
    X_val = pd.read_csv('../../data/processed/no_transformed/X_val_no_transform_selected.csv') # Contains selected features
    y_val = pd.read_csv('../../data/processed/no_transformed/y_val_no_transform.csv').values.ravel() # Flatten the array to 1D
    X_test = pd.read_csv('../../data/processed/no_transformed/X_test_no_transform_selected.csv') # Contains selected features
    y_test = pd.read_csv('../../data/processed/no_transformed/y_test_no_transform.csv').values.ravel() # Flatten the array to 1D
    print("Data loaded successfully.")
    print("X_train shape:", X_train.shape)
    print("X_validate shape:", X_val.shape)
    print("X_test shape:", X_test.shape)
except FileNotFoundError as e:
    print(f"Error loading data: {e}")
    print("Please ensure the data files are present in the correct paths.")
    # Exit or handle error appropriately
    exit() # Simple exit for script-like execution in notebook
# Out:
# Data loaded successfully.
# X_train shape: (4762, 10)
# X_validate shape: (984, 10)
# X_test shape: (984, 10)

# %% [markdown]
# ## 2. Define Model and Hyperparameter Space

# %%
gb = GradientBoostingClassifier(random_state=42)
param_distributions = {
    'n_estimators': randint(100, 601),
    'learning_rate': uniform(0.01, 0.2),
    'max_depth': randint(3, 11),
    'subsample': uniform(0.7, 0.3),
    'min_samples_split': randint(2, 11),
    'min_samples_leaf': randint(1, 5),
    'max_features': ['sqrt', 'log2', None] # Adjust if number of features is very small
}

# %% [markdown]
# ## 3. Setup Cross-Validation and Randomized Search

# %%
cv_strategy = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
scorer = make_scorer(brier_score_loss, needs_proba=True, greater_is_better=False)
random_search = RandomizedSearchCV(
    estimator=gb,
    param_distributions=param_distributions,
    n_iter=50,
    cv=cv_strategy,
    scoring=scorer,
    n_jobs=-1,
    random_state=42,
    verbose=1
)

# %% [markdown]
# ## 4. Run Hyperparameter Search

# %%
print("Starting Randomized Search CV for Gradient Boosting (Selected Features)...")
random_search.fit(X_train, y_train) # Fit on SELECTED features
print("Search complete.")
# Out:
# Starting Randomized Search CV for Gradient Boosting (Selected Features)...
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# Search complete.

# %% [markdown]
# ## 5. Analyze Search Results

# %%
print(f"Best Parameters found: {random_search.best_params_}")
print(f"Best Brier Score: {abs(random_search.best_score_):.4f}")
best_gb_selected_features = random_search.best_estimator_
# Out:
# Best Parameters found: {'learning_rate': 0.07095625163160581, 'max_depth': 8, 'max_features': None, 'min_samples_leaf': 1, 'min_samples_split': 6, 'n_estimators': 324, 'subsample': 0.7359596102001048}
# Best Brier Score: 0.0285

# %% [markdown]
# ## 6. Final Evaluation on Test Set

# %%
print("\n--- Evaluating Best Model on Test Set (Selected Features) ---")
y_pred_test = best_gb_selected_features.predict(X_test) # Use selected features
y_pred_proba_test = best_gb_selected_features.predict_proba(X_test)[:, 1] # Use selected features
# ... rest of evaluation code ...
print("Test Classification Report:")
print(classification_report(y_test, y_pred_test))
roc_auc_test = roc_auc_score(y_test, y_pred_proba_test)
pr_auc_test = average_precision_score(y_test, y_pred_proba_test)
print(f"Test ROC AUC Score: {roc_auc_test:.4f}")
print(f"Test Precision-Recall AUC Score: {pr_auc_test:.4f}")
print(f"Test Brier Score: {brier_score_loss(y_test, y_pred_proba_test):.4f}")
# Out:
# --- Evaluating Best Model on Test Set (Selected Features) ---
# Test Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.97      0.94      0.96       794
#            1       0.78      0.88      0.83       190
#
#     accuracy                           0.93       984
#    macro avg       0.88      0.91      0.89       984
# weighted avg       0.93      0.93      0.93       984
#
# Test ROC AUC Score: 0.9822
# Test Precision-Recall AUC Score: 0.9368
# Test Brier Score: 0.0543

# %%
# Compute calibration curve
prob_true_raw, prob_pred_raw = calibration_curve(y_test, y_pred_proba_test, n_bins=10, strategy='uniform')
# Plot calibration curve
plt.figure(figsize=(8, 6))
plt.plot(prob_pred_raw, prob_true_raw, marker='o', label='Original Model Calibration', linewidth=2)
plt.plot([0, 1], [0, 1], linestyle='--', color='gray', label='Perfectly Calibrated')
plt.xlabel("Predicted Probability")
plt.ylabel("True Probability (Fraction of Positives)")
plt.title("Calibration Curve")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 7.Calibration

# %%
from sklearn.calibration import CalibratedClassifierCV

base_model = best_gb_selected_features  # trained model from RandomizedSearchCV

# calibrate the model using isotonic regression
calibrated_model = CalibratedClassifierCV(base_model, method='isotonic', cv=5)
calibrated_model.fit(X_val, y_val)  # train calibrated model on validation set

# predict probabilities on the test set
y_pred_proba_calibrated = calibrated_model.predict_proba(X_test)[:, 1]

# Brier score
brier_score_calibrated = brier_score_loss(y_test, y_pred_proba_calibrated)
print(f"Calibrated Brier Score: {brier_score_calibrated:.4f}")
# Out:
# Calibrated Brier Score: 0.0556

# %%
# Compute calibration curve
prob_true, prob_pred = calibration_curve(y_test, y_pred_proba_calibrated, n_bins=10, strategy='uniform')
prob_true_raw, prob_pred_raw = calibration_curve(y_test, y_pred_proba_test, n_bins=10, strategy='uniform')
# Plot calibration curve
plt.figure(figsize=(8, 6))
plt.plot(prob_pred_raw, prob_true_raw, marker='o', label='Original Model Calibration', linewidth=2)
plt.plot(prob_pred, prob_true, marker='o', label='Calibrated Model Calibration', linewidth=2)
plt.plot([0, 1], [0, 1], linestyle='--', color='gray', label='Perfectly Calibrated')
plt.xlabel("Predicted Probability")
plt.ylabel("True Probability (Fraction of Positives)")
plt.title("Calibration Curve")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# ===== F1 vs Threshold
y_pred_proba_test = calibrated_model.predict_proba(X_test)[:, 1]

precision, recall, thresholds = precision_recall_curve(y_test, y_pred_proba_test)
f1_scores = 2 * (precision * recall) / (precision + recall + 1e-8)
best_index = np.argmax(f1_scores)
best_threshold = thresholds[best_index]
print(f"Best threshold (test): {best_threshold:.4f}")
# Out:
# Best threshold (test): 0.6127

# %% [markdown]
# ## 8. Plot Metrics (Test Set)

# %%
print("\n--- Evaluating Best Model on Test Set (Selected Features) ---")
y_pred_test = (y_pred_proba_test >= best_threshold).astype(int)
print("Test Classification Report:")
print(classification_report(y_test, y_pred_test))
roc_auc_test = roc_auc_score(y_test, y_pred_proba_test)
pr_auc_test = average_precision_score(y_test, y_pred_proba_test)
print(f"Test ROC AUC Score: {roc_auc_test:.4f}")
print(f"Test Precision-Recall AUC Score: {pr_auc_test:.4f}")
print(f"Test Brier Score: {brier_score_loss(y_test, y_pred_proba_test):.4f}")
# Out:
# --- Evaluating Best Model on Test Set (Selected Features) ---
# Test Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.94      0.98      0.96       794
#            1       0.89      0.73      0.80       190
#
#     accuracy                           0.93       984
#    macro avg       0.91      0.86      0.88       984
# weighted avg       0.93      0.93      0.93       984
#
# Test ROC AUC Score: 0.9637
# Test Precision-Recall AUC Score: 0.8900
# Test Brier Score: 0.0556

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

cm = confusion_matrix(y_test, y_pred_test)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot(cmap='Blues')
plt.title(f'Confusion Matrix (Threshold = {best_threshold:.4f})')
plt.show()

RocCurveDisplay.from_predictions(y_test, y_pred_proba_test, name='Calibrated Model')
plt.plot([0, 1], [0, 1], 'k--', label='Chance level')
plt.title('ROC Curve (Test Set)')
plt.grid(True)
plt.legend()
plt.show()

PrecisionRecallDisplay.from_predictions(y_test, y_pred_proba_test, name='Calibrated Model')
plt.title('Precision-Recall Curve (Test Set)')
plt.grid(True)
plt.show()

# %% [markdown]
# ## 9. Save the Final Model

# %%
# --- Placeholder: Define save path ---
model_save_path = '../../models/gb_model_selected_features_no_transformed.pkl'
joblib.dump(calibrated_model, model_save_path)
print(f"Best Gradient Boosting model (selected features with no transformation) saved to {model_save_path}")
# Out:
# Best Gradient Boosting model (selected features with no transformation) saved to ../../models/gb_model_selected_features_no_transformed.pkl
