# %%
pip install openpyxl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

df_raw = pd.read_excel(r"..\data\raw\Dataset\earthchem\earthchem_Australia_Cu_RockSamples.xlsx", header=6)
# Out:
#    SAMPLE ID  IGSN  SOURCE                                              DOI
# 0    142-279   NaN  GEOROC                         10.1093/petrology/egh014  \
# 1    142-194   NaN  GEOROC                         10.1093/petrology/egh014
# 2     142359   NaN  GEOROC                         10.1093/petrology/egh014
# 3     142360   NaN  GEOROC                         10.1093/petrology/egh014
# 4     142363   NaN  GEOROC                         10.1093/petrology/egh014
# 5     142368   NaN  GEOROC                         10.1093/petrology/egh014
# 6       2729   NaN  GEOROC  10.1130/0091-7613(1999)027<0075:EFCIOA>2.3.CO;2
# 7     84-438   NaN  GEOROC  10.1130/0091-7613(1999)027<0075:EFCIOA>2.3.CO;2
# 8     84-413   NaN  GEOROC  10.1130/0091-7613(1999)027<0075:EFCIOA>2.3.CO;2
# 9     85-168   NaN  GEOROC  10.1130/0091-7613(1999)027<0075:EFCIOA>2.3.CO;2
# 10     70997   NaN  GEOROC  10.1130/0091-7613(1999)027<0075:EFCIOA>2.3.CO;2
# ...

# %%
df_raw.head()
# Out:
#   SAMPLE ID  IGSN  SOURCE                       DOI
# 0   142-279   NaN  GEOROC  10.1093/petrology/egh014  \
# 1   142-194   NaN  GEOROC  10.1093/petrology/egh014
# 2    142359   NaN  GEOROC  10.1093/petrology/egh014
# 3    142360   NaN  GEOROC  10.1093/petrology/egh014
# 4    142363   NaN  GEOROC  10.1093/petrology/egh014
#
#                                                TITLE     JOURNAL
# 0  EVIDENCE FOR EARLY LREE-ENRICHED MANTLE SOURCE...  J. PETROL.  \
# 1  EVIDENCE FOR EARLY LREE-ENRICHED MANTLE SOURCE...  J. PETROL.
# 2  EVIDENCE FOR EARLY LREE-ENRICHED MANTLE SOURCE...  J. PETROL.
# 3  EVIDENCE FOR EARLY LREE-ENRICHED MANTLE SOURCE...  J. PETROL.
# 4  EVIDENCE FOR EARLY LREE-ENRICHED MANTLE SOURCE...  J. PETROL.
#
#                                            AUTHOR CRUISEID  LATITUDE
# 0  SMITHIES, R. H.; CHAMPION, D. C.; SUN, SHEN-SU      NaN     -20.8  \
# 1  SMITHIES, R. H.; CHAMPION, D. C.; SUN, SHEN-SU      NaN     -20.8
# ...

# %%
import geopandas as gpd
import matplotlib.pyplot as plt
import contextily as ctx
from shapely.geometry import Point

geometry = [Point(xy) for xy in zip(df_raw['LONGITUDE'], df_raw['LATITUDE'])]
gdf = gpd.GeoDataFrame(df_raw, geometry=geometry, crs='EPSG:4326')  

gdf_web = gdf.to_crs(epsg=3857)

fig, ax = plt.subplots(figsize=(10, 10))
gdf_web.plot(ax=ax, alpha=0.6, color='yellow', edgecolor='k')

ctx.add_basemap(ax, source=ctx.providers.OpenStreetMap.Mapnik)

ax.set_title('RockSamples geochemistry with Basemap')
ax.set_axis_off()
plt.tight_layout()
plt.show()
